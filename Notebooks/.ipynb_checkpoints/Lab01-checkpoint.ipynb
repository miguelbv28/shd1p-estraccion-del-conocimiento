# %%
pip install pandas numpy matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
import pandas as pd

# %%
# 1. Crear la carpeta Data si por alguna razón no se detecta
os.makedirs("../Data", exist_ok=True)

# %%
# 2. Crear datos simulados para Netflix.csv
datos_netflix = {
    'show_id': ['s1', 's2', 's3', 's4', 's5'],
    'type': ['Movie', 'TV Show', 'Movie', 'Movie', 'TV Show'],
    'title': ['Dick Johnson Is Dead', 'Blood & Water', 'Ganglands', 'Jailbirds New Orleans', 'Kota Factory'],
    'director': ['Kirsten Johnson', 'NaN', 'Julien Leclercq', 'NaN', 'NaN'],
    'country': ['United States', 'South Africa', 'France', 'NaN', 'India'],
    'release_year': [2020, 2021, 2021, 2021, 2021],
    'rating': ['PG-13', 'TV-MA', 'TV-MA', 'TV-MA', 'TV-MA'],
    'duration': ['90 min', '2 Seasons', '1 Season', '1 Season', '2 Seasons'],
    'listed_in': ['Documentaries', 'International TV Shows', 'Crime TV Shows', 'Docuseries', 'International TV Shows']
}

# %%
df_netflix = pd.DataFrame(datos_netflix)

# %%
df_netflix.to_csv('../Data/Netflix.csv', index=False)

# %%
# 3. Crear datos simulados para DataSet.csv (Amazon/Streaming alternativo)
datos_dataset = {
    'id': ['am1', 'am2', 'am3', 'am4', 'am5'],
    'title': ['The Grand Tour', 'The Boys', 'Fleabag', 'Tom Clancy\'s Jack Ryan', 'Invincible'],
    'genre': ['Entertainment', 'Action', 'Comedy', 'Action', 'Animation'],
    'platform': ['Amazon Prime', 'Amazon Prime', 'Amazon Prime', 'Amazon Prime', 'Amazon Prime'],
    'release_year': [2016, 2019, 2016, 2018, 2021],
    'user_rating': [4.7, 4.8, 4.6, 4.5, 4.8],
    'votes': [15000, 85000, 32000, 45000, 28000]
}

# %%
df_dataset = pd.DataFrame(datos_dataset)

# %%
df_dataset.to_csv('../Data/DataSet.csv', index=False)

# %%
df_netflix
# Out:
#   show_id     type                  title         director        country  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s2  TV Show          Blood & Water              NaN   South Africa
# 2      s3    Movie              Ganglands  Julien Leclercq         France
# 3      s4    Movie  Jailbirds New Orleans              NaN            NaN
# 4      s5  TV Show           Kota Factory              NaN          India
#
#    release_year rating   duration               listed_in
# 0          2020  PG-13     90 min           Documentaries
# 1          2021  TV-MA  2 Seasons  International TV Shows
# 2          2021  TV-MA   1 Season          Crime TV Shows
# 3          2021  TV-MA   1 Season              Docuseries
# 4          2021  TV-MA  2 Seasons  International TV Shows
